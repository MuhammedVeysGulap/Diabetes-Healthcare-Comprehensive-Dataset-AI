# %% [markdown]
# # Diabetes Healthcare: Comprehensive Dataset-AI

# %% [markdown]
# ## Kütüphanelerin İmport Edilmesi

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Veri Setinin Analizi

# %%
data = pd.read_csv("health care diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
data.shape # 768 satır(Örneklem), 9 kolon (Öznitelik)
# Out:
# (768, 9)

# %%
data.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
df = data.copy()

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### Veri Setinin Görselleştirilmesi

# %% [markdown]
# #### Diyabetik ve Diyabetik Olmayan Hastalar

# %%
sns.countplot(x="Outcome", data = df)
plt.xticks([0,1],["Diyabetik Olmayan","Diyabetik"])
plt.title("Diyabet Durum Dağılımı")
plt.xlabel("Diyabet Durumu")
plt.ylabel("Hasta Sayısı")
# Out:
# Text(0, 0.5, 'Hasta Sayısı')

# %% [markdown]
# #### Glucose Öznitelik Kolonunun Histogram Grafiği

# %%
df["Glucose"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### BloodPressure Öznitelik Kolonunun Histogram Grafiği

# %%
df["BloodPressure"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### SkinThickness Öznitelik Kolonunun Histogram Grafiği

# %%
df["SkinThickness"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### Insulin Öznitelik Kolonunun Histogram Grafiği

# %%
df["Insulin"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### BMI Öznitelik Kolonunun Histogram Grafiği

# %%
df["BMI"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### Değişken Tiplerinin Frekansı

# %%
# Değişken tipleri ve frekansları 
variable_types = df.dtypes.value_counts()

# Çubuk grafiği ile veri tiplerinin frekansını görselleştirme
plt.figure(figsize=(8, 6))
variable_types.plot(kind='bar', color='skyblue')
plt.title("Değişken Tiplerinin Frekansı")
plt.xlabel("Veri Tipi")
plt.ylabel("Sayı")
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, 'int64'), Text(1, 0, 'float64')])

# %% [markdown]
# #### Scatter Grafiği

# %%
sns.pairplot(df,hue='Outcome',corner=True)
plt.show()

# %% [markdown]
# #### Korelasyon Matrisi

# %%
corelation_matrix = df.corr()

# %%
corelation_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %% [markdown]
# #### Korelasyon Matrisi Grafiği

# %%
matrix = np.triu(df.corr())
sns.heatmap(corelation_matrix,mask= matrix);

# %% [markdown]
# #### Korelasyon Matrisinin Yorumu

# %%
'''
Yukarıdaki grafikte açık renkli değerler birbiriyle ilişkisi en yüksek öznitelikleri temsil etmektedir. Buna göre sonuç kolonuyla ilişkisi en yüksek olan;
- Glucose
- BMI 
öznitelik kolonlarını karşılaştırabiliriz.
'''
# Out:
# '\nYukarıdaki grafikte açık renkli değerler birbiriyle ilişkisi en yüksek öznitelikleri temsil etmektedir. Buna göre sonuç kolonuyla ilişkisi en yüksek olan;\n- Glucose\n- BMI \nöznitelik kolonlarını karşılaştırabiliriz.\n'

# %% [markdown]
# #### Sonuç Değeriyle En Yüksek İlişkili Değerlerin Grafikleri

# %%
sns.boxplot(x='Outcome', y='Glucose', data=df)
plt.title('Glucose & Outcome Boxplot')
plt.show()

# %%
sns.boxplot(x='Outcome', y='BMI', data=df)
plt.title('BMI & Outcome Boxplot')
plt.show()

# %% [markdown]
# ## Tahmin Modeli Algoritmaları

# %% [markdown]
# ### Lojistik Regresyon

# %%
X = df.drop("Outcome",axis=1)
y = df["Outcome"]

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,
                                                random_state=100)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg_model = LogisticRegression()

# %%
lg_model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lg_model.score(X_test,y_test)
# Out:
# 0.7447916666666666

# %%
lg_model.score(X_train,y_train)
# Out:
# 0.7951388888888888

# %% [markdown]
# **Model Tuning**

# %%
lg_model = LogisticRegression(C=0.1)
lg_model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=0.1)

# %%
lg_model.score(X_test,y_test)
# Out:
# 0.7447916666666666

# %%
lg_model.score(X_train,y_train)
# Out:
# 0.7916666666666666

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
y_pred=lg_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7447916666666666

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[107,  20],
#        [ 29,  36]], dtype=int64)

# %% [markdown]
# ### K-NN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
knn = KNeighborsClassifier(n_neighbors=3,metric='manhattan')

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=3)

# %%
y_pred = knn.predict(X_test)

# %%
knn.score(X_test,y_test)
# Out:
# 0.703125

# %%
knn.score(X_train,y_train)
# Out:
# 0.859375

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
print(cm)
# Out:
# [[104  23]
#  [ 34  31]]

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')


plt.xlabel('Tahmin Edilen Etiketler')
plt.ylabel('Gerçek Etiketler')
plt.title('Confusion Matrix')


plt.show()

# %% [markdown]
# ### Random Forest Classifier ROC and AOC Score

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,roc_auc_score

# %%
model = RandomForestClassifier(random_state=100)

# %%
model.fit(X_train, y_train)
sensitivity = cm[1, 1] / (cm[1, 0] + cm[1, 1])
specificity = cm[0, 0] / (cm[0, 0] + cm[0, 1])

# %%
# ROC eğrisi ve AUC hesaplama
y_probs = model.predict_proba(X_test)[:, 1]
auc = roc_auc_score(y_test, y_probs)

# %%
# Sınıflandırma raporu oluşturma
report = classification_report(y_test, y_pred)
print("Sınıflandırma Raporu:\n", report)
# Out:
# Sınıflandırma Raporu:
#                precision    recall  f1-score   support
#
#            0       0.75      0.82      0.78       127
#            1       0.57      0.48      0.52        65
#
#     accuracy                           0.70       192
#    macro avg       0.66      0.65      0.65       192
# weighted avg       0.69      0.70      0.70       192

# %%
# Duyarlılık, Özgüllük ve AUC değerlerini yazdırma
print("Duyarlılık (Sensitivity):", sensitivity)
print("Özgüllük (Specificity):", specificity)
print("ROC AUC:", auc)
# Out:
# Duyarlılık (Sensitivity): 0.47692307692307695
# Özgüllük (Specificity): 0.8188976377952756
# ROC AUC: 0.7604482132041187

# %% [markdown]
# ### Support Vector Machine

# %% [markdown]
# **Model**

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
svc.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred = svc.predict(X_test)

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[113,  14],
#        [ 34,  31]], dtype=int64)

# %%
svc.score(X_train,y_train)
# Out:
# 0.7743055555555556

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.75

# %% [markdown]
# #### Model Tuning

# %%
param_grid = {
    'C':[0.1,1,10,100],
    'kernel':['linear','rbf','poly']
}

# %%
grid_search = GridSearchCV(estimator=svc, 
                           param_grid=param_grid, 
                           cv=5, 
                           scoring='accuracy')

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100],
#                          'kernel': ['linear', 'rbf', 'poly']},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
svc= SVC(C=1,kernel="linear")

# %%
best_model = grid_search.best_estimator_

# %%
y_pred = best_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.734375

# %%
best_model.score(X_train,y_train)
# Out:
# 0.7881944444444444

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import  GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[103,  24],
#        [ 31,  34]], dtype=int64)

# %%
gnb.score(X_train,y_train)
# Out:
# 0.7777777777777778

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtc.predict(X_test)

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[101,  26],
#        [ 33,  32]], dtype=int64)

# %%
dtc.score(X_train,y_train)
# Out:
# 1.0

# %% [markdown]
# ### Random Forrest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc= RandomForestClassifier(n_estimators= 10,criterion ="entropy")

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_pred = rfc.predict(X_test)

# %%
cm= confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[107,  20],
#        [ 35,  30]], dtype=int64)

# %%
rfc.score(X_train,y_train)
# Out:
# 0.9861111111111112

# %%
from sklearn.metrics import classification_report

# %%
classification_rep = classification_report(y_test, y_pred)
print("Sınıflandırma Raporu:")
print(classification_rep)
# Out:
# Sınıflandırma Raporu:
#               precision    recall  f1-score   support
#
#            0       0.75      0.84      0.80       127
#            1       0.60      0.46      0.52        65
#
#     accuracy                           0.71       192
#    macro avg       0.68      0.65      0.66       192
# weighted avg       0.70      0.71      0.70       192
